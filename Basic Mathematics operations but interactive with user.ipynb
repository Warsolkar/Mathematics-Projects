# %%
'''Program of simple Addition, Multiplication
Subtraction and division but Interactive with 
appropriate user friendly display
'''

def add(a,b):
    c=a+b
    return c
def mult(a,b):
    c=a*b
    return c
def sub(a,b):
    c=a-b
    return c
def div(a,b):
    c=a//b
    return c

def select(a,b):
    if x=='A':
        print(a," + ",b,'= ',add(a,b))
    elif x=='M':
        print(a," * ",b,'= ',mult(a,b))
    elif x=='S':
        print(a," - ",b,'= ',sub(a,b))
    elif x=='D':
        
        print(a," / ",b,'= ',div(a,b))
        print('The Quotient is: ',a//b)
        print('The Remainder is: ',a%b)
    return

def repetition():
    a=int(input('Please enter the First Number: '))
    b=int(input('Please enter the Second Number: '))
    select(a,b)
    return

print('Please select "A" for Addition')
print('              "S" for Subtraction')
print('              "M" for Multiplication')
print('              "D" for Division:')
x=str(input())

if (x=='A'):
    print('You chose for Addition')
    repetition()
    
elif x=='M':
    print('You chose for Multiplication')
    repetition()
elif x=='S':
    print('You chose for Subtraction')
    repetition()
elif x=='D':
    print('You chose for Division')
    repetition()
    
else:
    print('You selected improper choice, please input proper selection, as shown above:.')
    x=str(input())
    if x=='A':
        print('You chose for Addition')
        repetition()
    elif x=='M':
        print('You chose for Multiplication')
        repetition()
    elif x=='S':
        print('You chose for Subtraction')
        repetition()
    elif x=='D':
        print('You chose for Division')
        repetition()
        
    else:
        print('You selected improper choice again, Good Bye ...!')
        pass
# Out:
# Please select "A" for Addition
#               "S" for Subtraction
#               "M" for Multiplication
#               "D" for Division:
# D
# You chose for Division
# Please enter the First Number: 34
# Please enter the Second Number: 3
# 34  /  3 =  11
# The Quotient is:  11
# The Remainder is:  1
